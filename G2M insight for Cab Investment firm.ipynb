# %% [markdown]
# #  Introduction

# %% [markdown]
# <p>
#     In the G2M insight for Cab Investment firm ( Must for all Specialization) project, we will show which company (Yellow Cab or Pink Cab) is the better opportunity to invest in it.
# </p>
# <p>
#     Here is some points before checking the results out:
#     <ul>
#         <li>
#             We use 5 datasets, "US Bank holidays.csv" is added dataset which describes US holidays :
#             <ul>
#                 <li>Cab_Data.csv</li>
#                 <li>City.csv</li>
#                 <li>Customer_ID.csv</li>
#                 <li>Transaction_ID.csv</li>
#                 <li>US Bank holidays.csv</li>
#             </ul>
#         </li>
#         <br>
#         <li>Profit is defined by me: Profit = Price Charged - Cost of Trip</li>
#         <br>
#         <li>
#             "df_total" is a dataframe is created by merging mentioned 5 dataframes :
#             <ul>
#                 <li>
#                     The days which is not a holiday, has "-" value in "Holiday" column
#                 </li>
#                 <li>
#                     After Merging if any record has at least 1 NaN value, the whole record is dropped. it means we do not have enough information of that trip
#                 </li>
#             </ul>
#         </li>
#         <br>
#         <li>Pickle is used for efficient working with jupyter, the parts related to "pkl" are commented</li>
#         <br>
#         <li>Hypothesis and Conclusions are provided in the other notebook</li>
#         <br>
#         <li>The profiling method helps me find informative data that guide me to take an analysis on the specific area and plot them, so profiling results are not discussed in detail but the files are attached, you can check it</li>
#         <br>
#     </ul>
# </p>

# %% [markdown]
# # Codes

# %% [markdown]
# ## Imports

# %%
import numpy as np
import pandas as pd
import plotly.offline as py
import plotly.graph_objects as go
from scipy import stats
import seaborn as sns
import matplotlib.pyplot as plt
import statistics as st
import geopy
from geopy import distance
import math
import folium
from folium.plugins import HeatMap
from scipy.optimize import curve_fit
import scipy
import random
import itertools
import plotly.express as px
from pandas_profiling import ProfileReport
from sklearn.linear_model import LinearRegression, Ridge, SGDRegressor
from sklearn.metrics import auc, accuracy_score, confusion_matrix, mean_squared_error
from sklearn.model_selection import cross_val_score, GridSearchCV, KFold, RandomizedSearchCV, train_test_split
from scipy.stats import uniform, randint
import xgboost as xgb
import sklearn.model_selection
import datetime
import pickle

# %% [markdown]
# ## Functions

# %%
def change_categorical_to_numerical (df):
    for column in df.select_dtypes(['object']).columns:
        df[column]= df[column].astype('category')
        df[column] = df[column].cat.codes
    return df

# %%
def report_best_scores(results, n_top=3):
    for i in range(1, n_top + 1):
        candidates = np.flatnonzero(results['rank_test_score'] == i)
        for candidate in candidates:
            print("Model with rank: {0}".format(i))
            print("Mean validation score: {0:.3f} (std: {1:.3f})".format(
                  results['mean_test_score'][candidate],
                  results['std_test_score'][candidate]))
            print("Parameters: {0}".format(results['params'][candidate]))
            print("")

# %% [markdown]
# ## Reading Data

# %%
df_cab = pd.read_csv('Data/Cab_Data.csv')
df_city = pd.read_csv('Data/City.csv')
df_customer = pd.read_csv('Data/Customer_ID.csv')
df_trans = pd.read_csv('Data/Transaction_ID.csv')
df_holidays = pd.read_csv('Data/US Bank holidays.csv')

# %%
# df_total = pd.read_pickle("df_total.pkl")

# %% [markdown]
# ## Describe data

# %% [markdown]
# ### df_cab

# %%
df_cab['Date of Travel'] = df_cab['Date of Travel'].apply(lambda x: datetime.date(1899, 12, 30)+datetime.timedelta(days=x))
df_cab['Date of Travel'] = pd.to_datetime(df_cab['Date of Travel'], infer_datetime_format=True)
# df_cab = df_cab.rename(columns={"Date of Travel": "Date"})

# %%
preview the data
df_cab.head()

# %%
df_cab.tail()

# %%
df_cab.info()

# %%
 df_cab.describe()

# %%
distribution of categorical features
df_cab.describe(include=['O'])

# %% [markdown]
# ### df_city

# %%
preview the data
df_city.head()

# %%
df_city.tail()

# %%
df_city.info()

# %%
 df_city.describe()

# %%
#distribution of categorical features
df_city.describe(include=['O'])

# %% [markdown]
# ### df_customer

# %%
preview the data
df_customer.head()

# %%
df_customer.tail()

# %%
df_customer.info()

# %%
 df_customer.describe()

# %%
distribution of categorical features
df_customer.describe(include=['O'])

# %% [markdown]
# ### df_trans

# %%
preview the data
df_trans.head()

# %%
df_trans.tail()

# %%
df_trans.info()

# %%
 df_trans.describe()

# %%
distribution of categorical features
df_trans.describe(include=['O'])

# %% [markdown]
# ### df_holidays

# %%
df_holidays['Date'] = pd.to_datetime(df_holidays['Date'], infer_datetime_format=True)
df_holidays

# %% [markdown]
# ## Merge

# %%
df_total = df_cab.merge(df_trans, how='outer').merge(df_customer, how='outer').merge(df_city, how='outer')
df_temp = df_cab.merge(df_holidays, how='outer', left_on='Date of Travel', right_on='Date')
df_temp = df_temp.fillna("-")
df_total = df_total.join(df_temp[['Holiday']])
df_total = df_total.sort_values(by='Date of Travel', ascending=True).reset_index(drop=True)
df_total.head()

# %%
df_total.tail()

# %%
df_total.info()

# %%
 df_total.describe()

# %%
distribution of categorical features
df_total.describe(include=['O'])

# %%
df_total.tail()

# %%
df_total['Profit'] = df_total['Price Charged'] - df_total['Cost of Trip']
df_total['Year'] = df_total['Date of Travel'].dt.year
df_total['Month'] = df_total['Date of Travel'].dt.month
df_total['Day of Week'] = df_total['Date of Travel'].dt.day_name()

# %% [markdown]
# ## NULL checking

# %%
# Null checking
df_total = df_total.dropna()
# df_total.to_pickle("df_total.pkl")

# %% [markdown]
# ## Profiling

# %%
profile_YellowCab= ProfileReport(df_total[df_total['Company'] == 'Yellow Cab'], title='Yellow Cab - Profiling Report', explorative=True)
profile_YellowCab.to_file("Yellow Cab - Profiling Report.html")

# %%
profile_PinkCab= ProfileReport(df_total[df_total['Company'] == 'Pink Cab'], title='Pink Cab - Profiling Report', explorative=True)
profile_PinkCab.to_file("Pink Cab - Profiling Report.html")

# %% [markdown]
# ## EDA and Plots

# %% [markdown]
# ### EDA

# %%
df_total.groupby(['Company']).mean().T

# %%
df_total.groupby(['Company'])[['Date of Travel', 'KM Travelled', 'Profit']].describe().T

# %%
df_total.groupby(['Company']).describe(include=['O']).T

# %% [markdown]
# ### Histograms

# %%
fig = px.histogram(df_total, x="Customer ID", color="Company", title="Customers Histogram - Check Retention of Customers by Company", color_discrete_map={'(?)':'black', 'Pink Cab':'#FC1CBF', 'Yellow Cab':'#FBE426'})
fig.write_html("Plot/Customers Histogram - Check Retention of Customers by Company.html", include_plotlyjs="cdn")

# %%
fig = px.histogram(df_total, x="Company", color="City", facet_row="Year", title="Cities Histogram - Check Count of Customers in Each Cities by Company")
fig.write_html("Plot/Cities Histogram - Check Count of Customers in Each Cities by Company.html", include_plotlyjs="cdn")

# %%
fig = px.histogram(df_total[df_total['Holiday'] != "-"], x="Holiday", color="City", facet_col="Company", facet_row="Year", title="Holiday's Transactions of Different Cities by Company in 3 Years")
fig.write_html("Plot/Holiday's Transactions of Different Cities by Company in 3 Years.html", include_plotlyjs="cdn")

# %% [markdown]
# ### Line Plot

# %%
df_temp = df_total.groupby(['Company', 'Day of Week']).sum()[['Profit']].reset_index()
#create a mapping of the sort order
sortbox = {'Monday':1,'Tuesday':2,'Wednesday':3,'Thursday':4,'Friday':5, 'Saturday':6,'Sunday':7}

#create new column with the sort order
df_temp['sort_column'] = df_temp['Day of Week'].map(sortbox)

#sort with sort_column

df_temp = df_temp.sort_values('sort_column').drop('sort_column',axis=1).reset_index(drop=True)

fig = px.line(df_temp, x="Day of Week", y="Profit", color= "Company", title="Days of Week's Sum of Profit by Company", color_discrete_map={'(?)':'black', 'Pink Cab':'#FC1CBF', 'Yellow Cab':'#cca300'})
fig.update_traces(mode='markers+lines')
fig.write_html("Plot/Days of Week's Sum of Profit by Company.html", include_plotlyjs="cdn")

# %%
df_temp = df_total.groupby(['Year', 'Company']).sum()[['Profit']].reset_index()
fig = px.line(df_temp, x="Year", y="Profit", color= "Company", title="Company's Profit by Year", color_discrete_map={'(?)':'black', 'Pink Cab':'#FC1CBF', 'Yellow Cab':'#cca300'})
fig.write_html("Plot/Company's Profit by Year.html", include_plotlyjs="cdn")

# %% [markdown]
# ### Bar Plot

# %%
df_temp = df_total.groupby(['Company', 'Year']).sum()[['Profit']].reset_index()
df_temp1 = df_total.groupby(['Company', 'Year']).sum()[['KM Travelled']].reset_index()
df_temp = df_temp.merge(df_temp1)
fig = px.bar(df_temp, x="KM Travelled", y="Profit", color= "Company", title="Company's Profit vs KM Travelled by Year", facet_col="Year" ,color_discrete_map={'(?)':'black', 'Pink Cab':'#FC1CBF', 'Yellow Cab':'#FBE426'})
fig.write_html("Plot/Company's Profit vs KM Travelledr by Year.html", include_plotlyjs="cdn")

# %%
df_temp = df_total.copy()
df_temp['Profit/KM'] = df_temp['Profit']/df_temp['KM Travelled']
df_temp = df_temp.groupby(['Company', 'Year']).mean()[['Profit/KM']].reset_index()
fig = px.bar(df_temp, x="Company", y="Profit/KM", color= "Company", title="Profit/Distance by Year", facet_col="Year" ,color_discrete_map={'(?)':'black', 'Pink Cab':'#FC1CBF', 'Yellow Cab':'#FBE426'})
fig.update_yaxes(title_text='Profit/Distance($/KM)')
fig.write_html("Plot/Profit-Distance by Year.html", include_plotlyjs="cdn")

# %%
df_temp = df_total.groupby(['Company', 'Day of Week']).count()[['Transaction ID']].reset_index()
#create a mapping of the sort order
sortbox = {'Monday':1,'Tuesday':2,'Wednesday':3,'Thursday':4,'Friday':5, 'Saturday':6,'Sunday':7}

#create new column with the sort order
df_temp['sort_column'] = df_temp['Day of Week'].map(sortbox)

#sort with sort_column

df_temp = df_temp.sort_values('sort_column').drop('sort_column',axis=1).reset_index(drop=True)

fig = px.bar(df_temp, x="Day of Week", y="Transaction ID", color= "Company", barmode='group', title="Count of trips by Days of week",
             color_discrete_map={'(?)':'black', 'Pink Cab':'#FC1CBF', 'Yellow Cab':'#FBE426'})
fig.update_yaxes(title_text='Count of Trips')
fig.write_html("Plot/Count of trips by Days of week.html", include_plotlyjs="cdn")

# %%
df_temp = df_total.groupby(['Company', 'Day of Week']).count()[['Transaction ID']].reset_index()
df_temp1 = df_total.groupby(['Day of Week']).count()[['Profit']].reset_index()
df_temp = df_temp.merge(df_temp1)
df_temp['Percent'] = (df_temp['Transaction ID']/df_temp['Profit'])*100
#create a mapping of the sort order
sortbox = {'Monday':1,'Tuesday':2,'Wednesday':3,'Thursday':4,'Friday':5, 'Saturday':6,'Sunday':7}

#create new column with the sort order
df_temp['sort_column'] = df_temp['Day of Week'].map(sortbox)

#sort with sort_column

df_temp = df_temp.sort_values('sort_column').drop('sort_column',axis=1).reset_index(drop=True)

fig = px.bar(df_temp, x="Day of Week", y="Percent", color= "Company", barmode='group', title="Market Share by Days of week",
             color_discrete_map={'(?)':'black', 'Pink Cab':'#FC1CBF', 'Yellow Cab':'#FBE426'})
fig.update_yaxes(title_text='Market share-Count of trips(%)')
fig.write_html("Plot/Market Share by Days of week.html", include_plotlyjs="cdn")

# %%
df_temp = df_total.groupby(['Company', 'Customer ID']).count()[['Users']].reset_index()
fig = px.histogram(df_temp, x="Users", color= "Company", barmode='group', title="User Retention",
             color_discrete_map={'(?)':'black', 'Pink Cab':'#FC1CBF', 'Yellow Cab':'#FBE426'})
fig.update_yaxes(title_text='Count of Users')
fig.update_xaxes(title_text='Number of trips')
fig.write_html("Plot/User Retention.html", include_plotlyjs="cdn")

# %% [markdown]
# ### Pie Chart

# %%
df_temp = df_total.groupby(['City','Company']).sum()[['Profit']].reset_index()
df_temp1 = df_total.groupby(['City','Company']).mean()[['Income (USD/Month)']].reset_index()
df_temp = df_temp.merge(df_temp1)
fig = px.sunburst(df_temp, path=['City', 'Company'], values='Profit', names='City',title='Sum of Profit of Companies in Different Cities - Check mean of Income of Customers',
                  color='City', hover_data=['Income (USD/Month)'], color_continuous_scale='RdBu')
fig.write_html("Plot/Sum of Profit of Companies in Different Cities - Check mean of Income of Customers.html", include_plotlyjs="cdn")

# %%
df_temp = df_total.groupby(['Company', 'Gender']).sum()[['Profit']].reset_index()
df_temp1 = df_total.groupby(['Company', 'Gender']).count()[['Customer ID']].reset_index()
df_temp = df_temp.merge(df_temp1)
fig = px.sunburst(df_temp, path=['Company', 'Gender'], values='Customer ID', names='Gender',title='Count of Customers by Company&Gender  - Check Sum of Profit of Each Gender by Company',
                  color='Company', hover_data=['Profit'], color_continuous_scale='RdBu', color_discrete_map={'(?)':'black', 'Pink Cab':'#FC1CBF', 'Yellow Cab':'#FBE426'})
fig.write_html("Plot/Count of Customers by Company&Gender  - Check Sum of Profit of Each Gender by Company.html", include_plotlyjs="cdn")

# %% [markdown]
# ## Model deployment

# %%
df_total_model = pd.get_dummies(df_total)
df_total_model.head()
# Out:
#    Transaction ID Date of Travel  KM Travelled  Price Charged  Cost of Trip  \
# 0      10000429.0     2016-01-02         15.15         342.62      205.4340
# 1      10000525.0     2016-01-02          2.18          51.47       26.4216
# 4      10000927.0     2016-01-02         34.56        1121.11      485.2224
# 5      10000721.0     2016-01-02         19.20         529.23      246.5280
# 7      10000519.0     2016-01-02         13.92         327.23      185.4144
#
#    Customer ID   Age  Income (USD/Month)  Population     Users  ...  \
# 0      57474.0  34.0             16558.0    248968.0   80021.0  ...
# 1       4551.0  19.0              6316.0   1955130.0  164468.0  ...
# 4       1808.0  59.0             18999.0   8405837.0  302149.0  ...
# 5       8117.0  21.0              5946.0   1595037.0  144132.0  ...
# 7       4429.0  20.0             23387.0   1955130.0  164468.0  ...
#
#    Holiday_Presidents Day (Washingtons Birthday)  Holiday_Thanksgiving Day  \
# 0                                              0                         0
# 1                                              0                         0
# 4                                              0                         0
# 5                                              0                         0
# 7                                              0                         0
#
#    Holiday_Veterans Day  Day of Week_Friday  Day of Week_Monday  \
# 0                     0                   0                   0
# 1                     0                   0                   0
# 4                     0                   0                   0
# 5                     0                   0                   0
# 7                     0                   0                   0
#
#    Day of Week_Saturday  Day of Week_Sunday  Day of Week_Thursday  \
# 0                     1                   0                     0
# 1                     1                   0                     0
# 4                     1                   0                     0
# 5                     1                   0                     0
# 7                     1                   0                     0
#
#    Day of Week_Tuesday  Day of Week_Wednesday
# 0                    0                      0
# 1                    0                      0
# 4                    0                      0
# 5                    0                      0
# 7                    0                      0
#
# [5 rows x 52 columns]

# %%
# Linear Correlation
corr = df_total_model.corr()
corr
# Out:
#                                                Transaction ID  KM Travelled  \
# Transaction ID                                       1.000000     -0.002233
# KM Travelled                                        -0.002233      1.000000
# Price Charged                                       -0.056536      0.827852
# Cost of Trip                                        -0.004350      0.982059
# Customer ID                                         -0.012192     -0.000457
# Age                                                 -0.001944      0.000148
# Income (USD/Month)                                  -0.000768     -0.000069
# Population                                           0.024949     -0.002704
# Users                                                0.015180     -0.000566
# Profit                                              -0.090022      0.475751
# Year                                                 0.941537     -0.002174
# Month                                                0.288707     -0.000994
# Company_Pink Cab                                     0.014456     -0.000293
# Company_Yellow Cab                                  -0.014456      0.000293
# City_ATLANTA GA                                     -0.000958     -0.003406
# City_AUSTIN TX                                       0.009795     -0.002846
# City_BOSTON MA                                      -0.013043      0.000346
# City_CHICAGO IL                                     -0.017263      0.002855
# City_DALLAS TX                                      -0.003016     -0.001053
# City_DENVER CO                                       0.001201     -0.001121
# City_LOS ANGELES CA                                 -0.011950      0.003753
# City_MIAMI FL                                        0.018847     -0.000432
# City_NASHVILLE TN                                    0.000521      0.001140
# City_NEW YORK NY                                     0.025810     -0.003166
# City_ORANGE COUNTY                                   0.006467     -0.002547
# City_PHOENIX AZ                                      0.000154     -0.002568
# City_PITTSBURGH PA                                   0.001702      0.000329
# City_SACRAMENTO CA                                   0.001239      0.001432
# City_SAN DIEGO CA                                   -0.018732      0.004511
# Payment_Mode_Card                                    0.001675      0.000387
# Payment_Mode_Cash                                   -0.001675     -0.000387
# Gender_Female                                        0.017503      0.000228
# Gender_Male                                         -0.017503     -0.000228
# Holiday_-                                           -0.008283     -0.005656
# Holiday_Christmas Day                                0.017072      0.000184
# Holiday_Columbus Day                                -0.000225      0.002404
# Holiday_Independence Day                             0.006126      0.004364
# Holiday_Labor Day                                   -0.002406     -0.001284
# Holiday_Martin Luther King Jr. Day                  -0.000327     -0.001663
# Holiday_Memorial Day                                -0.004022      0.001699
# Holiday_New Year Day                                -0.000240      0.000781
# Holiday_Presidents Day (Washingtons Birthday)       -0.008105      0.000803
# Holiday_Thanksgiving Day                             0.007372      0.004462
# Holiday_Veterans Day                                 0.000259      0.005030
# Day of Week_Friday                                   0.148050      0.000461
# Day of Week_Monday                                   0.001003     -0.002123
# Day of Week_Saturday                                 0.003813     -0.001005
# Day of Week_Sunday                                  -0.163395      0.002067
# Day of Week_Thursday                                -0.000730     -0.002760
# Day of Week_Tuesday                                  0.003199      0.005093
# Day of Week_Wednesday                                0.001466     -0.001993
#
#                                                Price Charged  Cost of Trip  \
# Transaction ID                                     -0.056536     -0.004350
# KM Travelled                                        0.827852      0.982059
# Price Charged                                       1.000000      0.854413
# Cost of Trip                                        0.854413      1.000000
# Customer ID                                        -0.173113     -0.008518
# Age                                                -0.004306      0.000257
# Income (USD/Month)                                  0.002984      0.000242
# Population                                          0.339265      0.018565
# Users                                               0.292723      0.021942
# Profit                                              0.879103      0.503462
# Year                                               -0.039995     -0.002938
# Month                                              -0.062747     -0.007342
# Company_Pink Cab                                   -0.242841     -0.132504
# Company_Yellow Cab                                  0.242841      0.132504
# City_ATLANTA GA                                    -0.025659     -0.003768
# City_AUSTIN TX                                     -0.025668     -0.008994
# City_BOSTON MA                                     -0.107841      0.006286
# City_CHICAGO IL                                    -0.155069      0.013153
# City_DALLAS TX                                      0.005276      0.000523
# City_DENVER CO                                     -0.023072     -0.006000
# City_LOS ANGELES CA                                -0.108153     -0.022568
# City_MIAMI FL                                      -0.020761     -0.004070
# City_NASHVILLE TN                                  -0.043666     -0.011563
# City_NEW YORK NY                                    0.343594      0.017909
# City_ORANGE COUNTY                                 -0.020139     -0.008186
# City_PHOENIX AZ                                    -0.021641     -0.007282
# City_PITTSBURGH PA                                 -0.024334     -0.006213
# City_SACRAMENTO CA                                 -0.037669     -0.008350
# City_SAN DIEGO CA                                  -0.021824     -0.003430
# Payment_Mode_Card                                  -0.000989      0.000746
# Payment_Mode_Cash                                   0.000989     -0.000746
# Gender_Female                                      -0.012704     -0.000991
# Gender_Male                                         0.012704      0.000991
# Holiday_-                                          -0.002349     -0.004819
# Holiday_Christmas Day                              -0.005346     -0.001262
# Holiday_Columbus Day                                0.006159      0.003021
# Holiday_Independence Day                            0.000221      0.004089
# Holiday_Labor Day                                   0.003537     -0.000537
# Holiday_Martin Luther King Jr. Day                 -0.005513     -0.002575
# Holiday_Memorial Day                               -0.000331      0.000985
# Holiday_New Year Day                               -0.006496     -0.001322
# Holiday_Presidents Day (Washingtons Birthday)       0.002894      0.000125
# Holiday_Thanksgiving Day                            0.005755      0.005293
# Holiday_Veterans Day                                0.005297      0.005828
# Day of Week_Friday                                  0.016092      0.000132
# Day of Week_Monday                                 -0.021981     -0.001782
# Day of Week_Saturday                                0.013099     -0.000737
# Day of Week_Sunday                                  0.036692      0.002130
# Day of Week_Thursday                               -0.029552     -0.003470
# Day of Week_Tuesday                                -0.017807      0.005101
# Day of Week_Wednesday                              -0.023359     -0.001532
#
#                                                Customer ID       Age  \
# Transaction ID                                   -0.012192 -0.001944
# KM Travelled                                     -0.000457  0.000148
# Price Charged                                    -0.173113 -0.004306
# Cost of Trip                                     -0.008518  0.000257
# Customer ID                                       1.000000 -0.004410
# Age                                              -0.004410  1.000000
# Income (USD/Month)                               -0.005401  0.003598
# Population                                       -0.598449 -0.013805
# Users                                            -0.679020 -0.010006
# Profit                                           -0.280051 -0.007396
# Year                                             -0.002539 -0.001125
# Month                                            -0.022517 -0.002574
# Company_Pink Cab                                  0.060192  0.001125
# Company_Yellow Cab                               -0.060192 -0.001125
# City_ATLANTA GA                                   0.134623 -0.000857
# City_AUSTIN TX                                    0.151011 -0.000408
# City_BOSTON MA                                    0.833730 -0.005405
# City_CHICAGO IL                                  -0.241925  0.012580
# City_DALLAS TX                                    0.103857  0.003894
# City_DENVER CO                                    0.114137 -0.002118
# City_LOS ANGELES CA                              -0.145351  0.010255
# City_MIAMI FL                                    -0.024225  0.006365
# City_NASHVILLE TN                                 0.235383 -0.009192
# City_NEW YORK NY                                 -0.478316 -0.016008
# City_ORANGE COUNTY                                0.019739 -0.000347
# City_PHOENIX AZ                                   0.041888 -0.000124
# City_PITTSBURGH PA                                0.132784  0.000703
# City_SACRAMENTO CA                                0.163834  0.001884
# City_SAN DIEGO CA                                 0.028111  0.000730
# Payment_Mode_Card                                -0.000994  0.002481
# Payment_Mode_Cash                                 0.000994 -0.002481
# Gender_Female                                     0.043704 -0.005637
# Gender_Male                                      -0.043704  0.005637
# Holiday_-                                        -0.013363 -0.010942
# Holiday_Christmas Day                             0.058521 -0.000429
# Holiday_Columbus Day                             -0.022193  0.002110
# Holiday_Independence Day                          0.022994 -0.008331
# Holiday_Labor Day                                -0.021607  0.010601
# Holiday_Martin Luther King Jr. Day                0.003747  0.004500
# Holiday_Memorial Day                              0.019151  0.001388
# Holiday_New Year Day                              0.028964 -0.000107
# Holiday_Presidents Day (Washingtons Birthday)    -0.000450 -0.004833
# Holiday_Thanksgiving Day                         -0.029573  0.013384
# Holiday_Veterans Day                             -0.025307  0.012578
# Day of Week_Friday                               -0.000955 -0.000688
# Day of Week_Monday                               -0.001917 -0.000311
# Day of Week_Saturday                             -0.000145  0.001533
# Day of Week_Sunday                                0.000423 -0.003013
# Day of Week_Thursday                              0.001899  0.001048
# Day of Week_Tuesday                              -0.000575  0.000023
# Day of Week_Wednesday                             0.001385  0.002174
#
#                                                Income (USD/Month)  Population  \
# Transaction ID                                          -0.000768    0.024949
# KM Travelled                                            -0.000069   -0.002704
# Price Charged                                            0.002984    0.339265
# Cost of Trip                                             0.000242    0.018565
# Customer ID                                             -0.005401   -0.598449
# Age                                                      0.003598   -0.013805
# Income (USD/Month)                                       1.000000    0.008709
# Population                                               0.008709    1.000000
# Users                                                    0.010389    0.932558
# Profit                                                   0.004740    0.547125
# Year                                                    -0.001005    0.000430
# Month                                                    0.000993    0.061341
# Company_Pink Cab                                        -0.000882   -0.161207
# Company_Yellow Cab                                       0.000882    0.161207
# City_ATLANTA GA                                         -0.003392   -0.147133
# City_AUSTIN TX                                          -0.006682   -0.122377
# City_BOSTON MA                                           0.001438   -0.361084
# City_CHICAGO IL                                          0.000405   -0.277807
# City_DALLAS TX                                          -0.005010   -0.135663
# City_DENVER CO                                          -0.001769   -0.106042
# City_LOS ANGELES CA                                     -0.001759   -0.298776
# City_MIAMI FL                                           -0.002130   -0.112253
# City_NASHVILLE TN                                       -0.004725   -0.106888
# City_NEW YORK NY                                         0.008375    0.988952
# City_ORANGE COUNTY                                       0.001412   -0.098579
# City_PHOENIX AZ                                         -0.000901   -0.072888
# City_PITTSBURGH PA                                      -0.005905   -0.066086
# City_SACRAMENTO CA                                       0.002005   -0.088801
# City_SAN DIEGO CA                                       -0.007062   -0.071846
# Payment_Mode_Card                                       -0.000081   -0.001534
# Payment_Mode_Cash                                        0.000081    0.001534
# Gender_Female                                           -0.001114   -0.039602
# Gender_Male                                              0.001114    0.039602
# Holiday_-                                               -0.015364    0.017387
# Holiday_Christmas Day                                   -0.000876   -0.053804
# Holiday_Columbus Day                                    -0.002366    0.018633
# Holiday_Independence Day                                 0.004063   -0.011229
# Holiday_Labor Day                                        0.016286    0.018627
# Holiday_Martin Luther King Jr. Day                      -0.000258   -0.025969
# Holiday_Memorial Day                                    -0.002951   -0.002922
# Holiday_New Year Day                                    -0.002152   -0.027421
# Holiday_Presidents Day (Washingtons Birthday)            0.010193   -0.003105
# Holiday_Thanksgiving Day                                 0.012832    0.024197
# Holiday_Veterans Day                                     0.011901    0.013027
# Day of Week_Friday                                       0.003695   -0.000423
# Day of Week_Monday                                       0.000819    0.002090
# Day of Week_Saturday                                    -0.003209   -0.001072
# Day of Week_Sunday                                      -0.001139    0.001091
# Day of Week_Thursday                                     0.000560   -0.002779
# Day of Week_Tuesday                                      0.000796   -0.000394
# Day of Week_Wednesday                                   -0.001411    0.002124
#
#                                                   Users    Profit  ...  \
# Transaction ID                                 0.015180 -0.090022  ...
# KM Travelled                                  -0.000566  0.475751  ...
# Price Charged                                  0.292723  0.879103  ...
# Cost of Trip                                   0.021942  0.503462  ...
# Customer ID                                   -0.679020 -0.280051  ...
# Age                                           -0.010006 -0.007396  ...
# Income (USD/Month)                             0.010389  0.004740  ...
# Population                                     0.932558  0.547125  ...
# Users                                          1.000000  0.466632  ...
# Profit                                         0.466632  1.000000  ...
# Year                                           0.000065 -0.063811  ...
# Month                                          0.035889 -0.097605  ...
# Company_Pink Cab                              -0.170689 -0.282265  ...
# Company_Yellow Cab                             0.170689  0.282265  ...
# City_ATLANTA GA                               -0.245627 -0.039210  ...
# City_AUSTIN TX                                -0.209220 -0.034432  ...
# City_BOSTON MA                                -0.324750 -0.185092  ...
# City_CHICAGO IL                               -0.065706 -0.269924  ...
# City_DALLAS TX                                -0.240376  0.008294  ...
# City_DENVER CO                                -0.187460 -0.032862  ...
# City_LOS ANGELES CA                           -0.148425 -0.159143  ...
# City_MIAMI FL                                 -0.236915 -0.030789  ...
# City_NASHVILLE TN                             -0.169207 -0.062004  ...
# City_NEW YORK NY                               0.890127  0.554924  ...
# City_ORANGE COUNTY                            -0.190661 -0.025979  ...
# City_PHOENIX AZ                               -0.142477 -0.029307  ...
# City_PITTSBURGH PA                            -0.115128 -0.034765  ...
# City_SACRAMENTO CA                            -0.151852 -0.054979  ...
# City_SAN DIEGO CA                             -0.088732 -0.033144  ...
# Payment_Mode_Card                             -0.001276 -0.002328  ...
# Payment_Mode_Cash                              0.001276  0.002328  ...
# Gender_Female                                 -0.054930 -0.020215  ...
# Gender_Male                                    0.054930  0.020215  ...
# Holiday_-                                      0.033977  0.000514  ...
# Holiday_Christmas Day                         -0.094188 -0.007732  ...
# Holiday_Columbus Day                           0.022891  0.007470  ...
# Holiday_Independence Day                      -0.006225 -0.003384  ...
# Holiday_Labor Day                              0.023176  0.006375  ...
# Holiday_Martin Luther King Jr. Day            -0.037218 -0.006806  ...
# Holiday_Memorial Day                           0.000422 -0.001453  ...
# Holiday_New Year Day                          -0.048106 -0.009589  ...
# Holiday_Presidents Day (Washingtons Birthday) -0.006656  0.004698  ...
# Holiday_Thanksgiving Day                       0.030349  0.004714  ...
# Holiday_Veterans Day                           0.020950  0.003461  ...
# Day of Week_Friday                            -0.000389  0.026638  ...
# Day of Week_Monday                             0.002156 -0.034917  ...
# Day of Week_Saturday                           0.000071  0.022459  ...
# Day of Week_Sunday                             0.000296  0.059060  ...
# Day of Week_Thursday                          -0.002365 -0.045958  ...
# Day of Week_Tuesday                           -0.000395 -0.034289  ...
# Day of Week_Wednesday                          0.000975 -0.037437  ...
#
#                                                Holiday_Presidents Day (Washingtons Birthday)  \
# Transaction ID                                                                     -0.008105
# KM Travelled                                                                        0.000803
# Price Charged                                                                       0.002894
# Cost of Trip                                                                        0.000125
# Customer ID                                                                        -0.000450
# Age                                                                                -0.004833
# Income (USD/Month)                                                                  0.010193
# Population                                                                         -0.003105
# Users                                                                              -0.006656
# Profit                                                                              0.004698
# Year                                                                               -0.006666
# Month                                                                              -0.006167
# Company_Pink Cab                                                                    0.004647
# Company_Yellow Cab                                                                 -0.004647
# City_ATLANTA GA                                                                    -0.005927
# City_AUSTIN TX                                                                      0.069952
# City_BOSTON MA                                                                     -0.012260
# City_CHICAGO IL                                                                    -0.017928
# City_DALLAS TX                                                                     -0.005706
# City_DENVER CO                                                                     -0.004188
# City_LOS ANGELES CA                                                                 0.019693
# City_MIAMI FL                                                                      -0.005467
# City_NASHVILLE TN                                                                  -0.003710
# City_NEW YORK NY                                                                   -0.002484
# City_ORANGE COUNTY                                                                 -0.004275
# City_PHOENIX AZ                                                                    -0.003067
# City_PITTSBURGH PA                                                                 -0.002443
# City_SACRAMENTO CA                                                                 -0.003286
# City_SAN DIEGO CA                                                                   0.004105
# Payment_Mode_Card                                                                   0.001158
# Payment_Mode_Cash                                                                  -0.001158
# Gender_Female                                                                      -0.007560
# Gender_Male                                                                         0.007560
# Holiday_-                                                                          -0.258448
# Holiday_Christmas Day                                                              -0.002182
# Holiday_Columbus Day                                                               -0.001396
# Holiday_Independence Day                                                           -0.001433
# Holiday_Labor Day                                                                  -0.001434
# Holiday_Martin Luther King Jr. Day                                                 -0.001224
# Holiday_Memorial Day                                                               -0.001436
# Holiday_New Year Day                                                               -0.001085
# Holiday_Presidents Day (Washingtons Birthday)                                       1.000000
# Holiday_Thanksgiving Day                                                           -0.001869
# Holiday_Veterans Day                                                               -0.001664
# Day of Week_Friday                                                                 -0.004222
# Day of Week_Monday                                                                  0.003602
# Day of Week_Saturday                                                                0.000651
# Day of Week_Sunday                                                                  0.002086
# Day of Week_Thursday                                                                0.001063
# Day of Week_Tuesday                                                                -0.000030
# Day of Week_Wednesday                                                              -0.002342
#
#                                                Holiday_Thanksgiving Day  \
# Transaction ID                                                 0.007372
# KM Travelled                                                   0.004462
# Price Charged                                                  0.005755
# Cost of Trip                                                   0.005293
# Customer ID                                                   -0.029573
# Age                                                            0.013384
# Income (USD/Month)                                             0.012832
# Population                                                     0.024197
# Users                                                          0.030349
# Profit                                                         0.004714
# Year                                                           0.004668
# Month                                                          0.008979
# Company_Pink Cab                                              -0.005033
# Company_Yellow Cab                                             0.005033
# City_ATLANTA GA                                               -0.008786
# City_AUSTIN TX                                                -0.007037
# City_BOSTON MA                                                -0.018172
# City_CHICAGO IL                                                0.032547
# City_DALLAS TX                                                -0.008458
# City_DENVER CO                                                -0.006208
# City_LOS ANGELES CA                                           -0.024015
# City_MIAMI FL                                                 -0.008103
# City_NASHVILLE TN                                             -0.005499
# City_NEW YORK NY                                               0.019968
# City_ORANGE COUNTY                                            -0.006336
# City_PHOENIX AZ                                               -0.004546
# City_PITTSBURGH PA                                            -0.003621
# City_SACRAMENTO CA                                            -0.004871
# City_SAN DIEGO CA                                              0.000322
# Payment_Mode_Card                                              0.000483
# Payment_Mode_Cash                                             -0.000483
# Gender_Female                                                  0.011613
# Gender_Male                                                   -0.011613
# Holiday_-                                                     -0.383083
# Holiday_Christmas Day                                         -0.003235
# Holiday_Columbus Day                                          -0.002069
# Holiday_Independence Day                                      -0.002123
# Holiday_Labor Day                                             -0.002126
# Holiday_Martin Luther King Jr. Day                            -0.001815
# Holiday_Memorial Day                                          -0.002128
# Holiday_New Year Day                                          -0.001608
# Holiday_Presidents Day (Washingtons Birthday)                 -0.001869
# Holiday_Thanksgiving Day                                       1.000000
# Holiday_Veterans Day                                          -0.002467
# Day of Week_Friday                                            -0.000707
# Day of Week_Monday                                             0.001735
# Day of Week_Saturday                                          -0.004056
# Day of Week_Sunday                                             0.002762
# Day of Week_Thursday                                          -0.000854
# Day of Week_Tuesday                                            0.005009
# Day of Week_Wednesday                                         -0.002597
#
#                                                Holiday_Veterans Day  \
# Transaction ID                                             0.000259
# KM Travelled                                               0.005030
# Price Charged                                              0.005297
# Cost of Trip                                               0.005828
# Customer ID                                               -0.025307
# Age                                                        0.012578
# Income (USD/Month)                                         0.011901
# Population                                                 0.013027
# Users                                                      0.020950
# Profit                                                     0.003461
# Year                                                       0.000259
# Month                                                      0.001298
# Company_Pink Cab                                          -0.006460
# Company_Yellow Cab                                         0.006460
# City_ATLANTA GA                                           -0.007824
# City_AUSTIN TX                                            -0.006267
# City_BOSTON MA                                            -0.016183
# City_CHICAGO IL                                            0.040016
# City_DALLAS TX                                            -0.007532
# City_DENVER CO                                            -0.005528
# City_LOS ANGELES CA                                       -0.021386
# City_MIAMI FL                                             -0.007216
# City_NASHVILLE TN                                         -0.004897
# City_NEW YORK NY                                           0.008328
# City_ORANGE COUNTY                                        -0.005642
# City_PHOENIX AZ                                           -0.004048
# City_PITTSBURGH PA                                        -0.003224
# City_SACRAMENTO CA                                        -0.004337
# City_SAN DIEGO CA                                          0.001406
# Payment_Mode_Card                                         -0.000507
# Payment_Mode_Cash                                          0.000507
# Gender_Female                                              0.019491
# Gender_Male                                               -0.019491
# Holiday_-                                                 -0.341148
# Holiday_Christmas Day                                     -0.002881
# Holiday_Columbus Day                                      -0.001842
# Holiday_Independence Day                                  -0.001891
# Holiday_Labor Day                                         -0.001893
# Holiday_Martin Luther King Jr. Day                        -0.001616
# Holiday_Memorial Day                                      -0.001895
# Holiday_New Year Day                                      -0.001432
# Holiday_Presidents Day (Washingtons Birthday)             -0.001664
# Holiday_Thanksgiving Day                                  -0.002467
# Holiday_Veterans Day                                       1.000000
# Day of Week_Friday                                        -0.000060
# Day of Week_Monday                                         0.000061
# Day of Week_Saturday                                       0.000949
# Day of Week_Sunday                                         0.000235
# Day of Week_Thursday                                      -0.001073
# Day of Week_Tuesday                                        0.001496
# Day of Week_Wednesday                                     -0.001994
#
#                                                Day of Week_Friday  \
# Transaction ID                                           0.148050
# KM Travelled                                             0.000461
# Price Charged                                            0.016092
# Cost of Trip                                             0.000132
# Customer ID                                             -0.000955
# Age                                                     -0.000688
# Income (USD/Month)                                       0.003695
# Population                                              -0.000423
# Users                                                   -0.000389
# Profit                                                   0.026638
# Year                                                     0.157520
# Month                                                   -0.000544
# Company_Pink Cab                                         0.001530
# Company_Yellow Cab                                      -0.001530
# City_ATLANTA GA                                          0.000744
# City_AUSTIN TX                                          -0.001922
# City_BOSTON MA                                          -0.000284
# City_CHICAGO IL                                         -0.001211
# City_DALLAS TX                                          -0.001567
# City_DENVER CO                                          -0.000072
# City_LOS ANGELES CA                                      0.003277
# City_MIAMI FL                                            0.001472
# City_NASHVILLE TN                                       -0.001199
# City_NEW YORK NY                                        -0.000569
# City_ORANGE COUNTY                                       0.001696
# City_PHOENIX AZ                                          0.004571
# City_PITTSBURGH PA                                      -0.000158
# City_SACRAMENTO CA                                       0.000478
# City_SAN DIEGO CA                                       -0.008567
# Payment_Mode_Card                                        0.001309
# Payment_Mode_Cash                                       -0.001309
# Gender_Female                                            0.004761
# Gender_Male                                             -0.004761
# Holiday_-                                               -0.005714
# Holiday_Christmas Day                                    0.007911
# Holiday_Columbus Day                                     0.001671
# Holiday_Independence Day                                 0.002222
# Holiday_Labor Day                                        0.000471
# Holiday_Martin Luther King Jr. Day                       0.002753
# Holiday_Memorial Day                                     0.001484
# Holiday_New Year Day                                     0.004812
# Holiday_Presidents Day (Washingtons Birthday)           -0.004222
# Holiday_Thanksgiving Day                                -0.000707
# Holiday_Veterans Day                                    -0.000060
# Day of Week_Friday                                       1.000000
# Day of Week_Monday                                      -0.162870
# Day of Week_Saturday                                    -0.285218
# Day of Week_Sunday                                      -0.267141
# Day of Week_Thursday                                    -0.190458
# Day of Week_Tuesday                                     -0.162601
# Day of Week_Wednesday                                   -0.163612
#
#                                                Day of Week_Monday  \
# Transaction ID                                           0.001003
# KM Travelled                                            -0.002123
# Price Charged                                           -0.021981
# Cost of Trip                                            -0.001782
# Customer ID                                             -0.001917
# Age                                                     -0.000311
# Income (USD/Month)                                       0.000819
# Population                                               0.002090
# Users                                                    0.002156
# Profit                                                  -0.034917
# Year                                                     0.005837
# Month                                                   -0.010102
# Company_Pink Cab                                         0.001064
# Company_Yellow Cab                                      -0.001064
# City_ATLANTA GA                                         -0.003284
# City_AUSTIN TX                                          -0.000880
# City_BOSTON MA                                          -0.001796
# City_CHICAGO IL                                         -0.002551
# City_DALLAS TX                                           0.002309
# City_DENVER CO                                           0.001130
# City_LOS ANGELES CA                                      0.002515
# City_MIAMI FL                                           -0.000897
# City_NASHVILLE TN                                        0.001867
# City_NEW YORK NY                                         0.002027
# City_ORANGE COUNTY                                      -0.000212
# City_PHOENIX AZ                                         -0.002961
# City_PITTSBURGH PA                                      -0.001351
# City_SACRAMENTO CA                                      -0.001093
# City_SAN DIEGO CA                                        0.002683
# Payment_Mode_Card                                       -0.004423
# Payment_Mode_Cash                                        0.004423
# Gender_Female                                           -0.000033
# Gender_Male                                              0.000033
# Holiday_-                                               -0.002682
# Holiday_Christmas Day                                   -0.000463
# Holiday_Columbus Day                                     0.001412
# Holiday_Independence Day                                 0.001082
# Holiday_Labor Day                                       -0.000236
# Holiday_Martin Luther King Jr. Day                       0.003959
# Holiday_Memorial Day                                    -0.001550
# Holiday_New Year Day                                     0.000167
# Holiday_Presidents Day (Washingtons Birthday)            0.003602
# Holiday_Thanksgiving Day                                 0.001735
# Holiday_Veterans Day                                     0.000061
# Day of Week_Friday                                      -0.162870
# Day of Week_Monday                                       1.000000
# Day of Week_Saturday                                    -0.158730
# Day of Week_Sunday                                      -0.148670
# Day of Week_Thursday                                    -0.105994
# Day of Week_Tuesday                                     -0.090491
# Day of Week_Wednesday                                   -0.091054
#
#                                                Day of Week_Saturday  \
# Transaction ID                                             0.003813
# KM Travelled                                              -0.001005
# Price Charged                                              0.013099
# Cost of Trip                                              -0.000737
# Customer ID                                               -0.000145
# Age                                                        0.001533
# Income (USD/Month)                                        -0.003209
# Population                                                -0.001072
# Users                                                      0.000071
# Profit                                                     0.022459
# Year                                                      -0.002541
# Month                                                      0.016833
# Company_Pink Cab                                          -0.004079
# Company_Yellow Cab                                         0.004079
# City_ATLANTA GA                                            0.001140
# City_AUSTIN TX                                            -0.001385
# City_BOSTON MA                                             0.000189
# City_CHICAGO IL                                            0.003254
# City_DALLAS TX                                             0.001540
# City_DENVER CO                                            -0.000521
# City_LOS ANGELES CA                                       -0.000613
# City_MIAMI FL                                             -0.002822
# City_NASHVILLE TN                                         -0.001153
# City_NEW YORK NY                                          -0.001322
# City_ORANGE COUNTY                                        -0.001841
# City_PHOENIX AZ                                           -0.002530
# City_PITTSBURGH PA                                        -0.002869
# City_SACRAMENTO CA                                         0.002574
# City_SAN DIEGO CA                                          0.002979
# Payment_Mode_Card                                          0.000411
# Payment_Mode_Cash                                         -0.000411
# Gender_Female                                             -0.000955
# Gender_Male                                                0.000955
# Holiday_-                                                  0.005238
# Holiday_Christmas Day                                     -0.004710
# Holiday_Columbus Day                                      -0.002111
# Holiday_Independence Day                                   0.000749
# Holiday_Labor Day                                         -0.000808
# Holiday_Martin Luther King Jr. Day                        -0.003281
# Holiday_Memorial Day                                       0.001946
# Holiday_New Year Day                                      -0.005000
# Holiday_Presidents Day (Washingtons Birthday)              0.000651
# Holiday_Thanksgiving Day                                  -0.004056
# Holiday_Veterans Day                                       0.000949
# Day of Week_Friday                                        -0.285218
# Day of Week_Monday                                        -0.158730
# Day of Week_Saturday                                       1.000000
# Day of Week_Sunday                                        -0.260352
# Day of Week_Thursday                                      -0.185618
# Day of Week_Tuesday                                       -0.158469
# Day of Week_Wednesday                                     -0.159454
#
#                                                Day of Week_Sunday  \
# Transaction ID                                          -0.163395
# KM Travelled                                             0.002067
# Price Charged                                            0.036692
# Cost of Trip                                             0.002130
# Customer ID                                              0.000423
# Age                                                     -0.003013
# Income (USD/Month)                                      -0.001139
# Population                                               0.001091
# Users                                                    0.000296
# Profit                                                   0.059060
# Year                                                    -0.171596
# Month                                                    0.000332
# Company_Pink Cab                                        -0.001487
# Company_Yellow Cab                                       0.001487
# City_ATLANTA GA                                          0.002475
# City_AUSTIN TX                                           0.003107
# City_BOSTON MA                                          -0.000644
# City_CHICAGO IL                                          0.000583
# City_DALLAS TX                                          -0.001653
# City_DENVER CO                                          -0.000534
# City_LOS ANGELES CA                                     -0.003939
# City_MIAMI FL                                            0.001125
# City_NASHVILLE TN                                        0.002265
# City_NEW YORK NY                                         0.001263
# City_ORANGE COUNTY                                      -0.002943
# City_PHOENIX AZ                                          0.000565
# City_PITTSBURGH PA                                      -0.001242
# City_SACRAMENTO CA                                      -0.000989
# City_SAN DIEGO CA                                        0.005064
# Payment_Mode_Card                                       -0.000140
# Payment_Mode_Cash                                        0.000140
# Gender_Female                                           -0.002431
# Gender_Male                                              0.002431
# Holiday_-                                               -0.002052
# Holiday_Christmas Day                                    0.000642
# Holiday_Columbus Day                                     0.001773
# Holiday_Independence Day                                -0.001976
# Holiday_Labor Day                                       -0.000449
# Holiday_Martin Luther King Jr. Day                      -0.000234
# Holiday_Memorial Day                                    -0.000493
# Holiday_New Year Day                                     0.002080
# Holiday_Presidents Day (Washingtons Birthday)            0.002086
# Holiday_Thanksgiving Day                                 0.002762
# Holiday_Veterans Day                                     0.000235
# Day of Week_Friday                                      -0.267141
# Day of Week_Monday                                      -0.148670
# Day of Week_Saturday                                    -0.260352
# Day of Week_Sunday                                       1.000000
# Day of Week_Thursday                                    -0.173853
# Day of Week_Tuesday                                     -0.148425
# Day of Week_Wednesday                                   -0.149348
#
#                                                Day of Week_Thursday  \
# Transaction ID                                            -0.000730
# KM Travelled                                              -0.002760
# Price Charged                                             -0.029552
# Cost of Trip                                              -0.003470
# Customer ID                                                0.001899
# Age                                                        0.001048
# Income (USD/Month)                                         0.000560
# Population                                                -0.002779
# Users                                                     -0.002365
# Profit                                                    -0.045958
# Year                                                       0.000096
# Month                                                     -0.003574
# Company_Pink Cab                                           0.004672
# Company_Yellow Cab                                        -0.004672
# City_ATLANTA GA                                           -0.003905
# City_AUSTIN TX                                             0.001924
# City_BOSTON MA                                             0.001581
# City_CHICAGO IL                                            0.001066
# City_DALLAS TX                                             0.000159
# City_DENVER CO                                            -0.001163
# City_LOS ANGELES CA                                        0.000939
# City_MIAMI FL                                              0.000781
# City_NASHVILLE TN                                          0.002666
# City_NEW YORK NY                                          -0.002776
# City_ORANGE COUNTY                                         0.003944
# City_PHOENIX AZ                                           -0.001285
# City_PITTSBURGH PA                                         0.000536
# City_SACRAMENTO CA                                        -0.002500
# City_SAN DIEGO CA                                         -0.000072
# Payment_Mode_Card                                         -0.003241
# Payment_Mode_Cash                                          0.003241
# Gender_Female                                             -0.002749
# Gender_Male                                                0.002749
# Holiday_-                                                  0.003099
# Holiday_Christmas Day                                     -0.002372
# Holiday_Columbus Day                                      -0.003624
# Holiday_Independence Day                                  -0.000272
# Holiday_Labor Day                                          0.000549
# Holiday_Martin Luther King Jr. Day                        -0.001165
# Holiday_Memorial Day                                      -0.000050
# Holiday_New Year Day                                      -0.001378
# Holiday_Presidents Day (Washingtons Birthday)              0.001063
# Holiday_Thanksgiving Day                                  -0.000854
# Holiday_Veterans Day                                      -0.001073
# Day of Week_Friday                                        -0.190458
# Day of Week_Monday                                        -0.105994
# Day of Week_Saturday                                      -0.185618
# Day of Week_Sunday                                        -0.173853
# Day of Week_Thursday                                       1.000000
# Day of Week_Tuesday                                       -0.105819
# Day of Week_Wednesday                                     -0.106477
#
#                                                Day of Week_Tuesday  \
# Transaction ID                                            0.003199
# KM Travelled                                              0.005093
# Price Charged                                            -0.017807
# Cost of Trip                                              0.005101
# Customer ID                                              -0.000575
# Age                                                       0.000023
# Income (USD/Month)                                        0.000796
# Population                                               -0.000394
# Users                                                    -0.000395
# Profit                                                   -0.034289
# Year                                                      0.005814
# Month                                                    -0.009918
# Company_Pink Cab                                          0.000790
# Company_Yellow Cab                                       -0.000790
# City_ATLANTA GA                                          -0.000493
# City_AUSTIN TX                                            0.001123
# City_BOSTON MA                                           -0.000598
# City_CHICAGO IL                                           0.001205
# City_DALLAS TX                                           -0.000698
# City_DENVER CO                                            0.000456
# City_LOS ANGELES CA                                      -0.000167
# City_MIAMI FL                                            -0.000065
# City_NASHVILLE TN                                        -0.003576
# City_NEW YORK NY                                         -0.000546
# City_ORANGE COUNTY                                        0.000117
# City_PHOENIX AZ                                           0.002275
# City_PITTSBURGH PA                                        0.003461
# City_SACRAMENTO CA                                        0.001968
# City_SAN DIEGO CA                                        -0.002749
# Payment_Mode_Card                                         0.003431
# Payment_Mode_Cash                                        -0.003431
# Gender_Female                                             0.001689
# Gender_Male                                              -0.001689
# Holiday_-                                                -0.002039
# Holiday_Christmas Day                                    -0.000195
# Holiday_Columbus Day                                      0.001118
# Holiday_Independence Day                                 -0.002434
# Holiday_Labor Day                                         0.001737
# Holiday_Martin Luther King Jr. Day                       -0.000161
# Holiday_Memorial Day                                     -0.000226
# Holiday_New Year Day                                     -0.001510
# Holiday_Presidents Day (Washingtons Birthday)            -0.000030
# Holiday_Thanksgiving Day                                  0.005009
# Holiday_Veterans Day                                      0.001496
# Day of Week_Friday                                       -0.162601
# Day of Week_Monday                                       -0.090491
# Day of Week_Saturday                                     -0.158469
# Day of Week_Sunday                                       -0.148425
# Day of Week_Thursday                                     -0.105819
# Day of Week_Tuesday                                       1.000000
# Day of Week_Wednesday                                    -0.090904
#
#                                                Day of Week_Wednesday
# Transaction ID                                              0.001466
# KM Travelled                                               -0.001993
# Price Charged                                              -0.023359
# Cost of Trip                                               -0.001532
# Customer ID                                                 0.001385
# Age                                                         0.002174
# Income (USD/Month)                                         -0.001411
# Population                                                  0.002124
# Users                                                       0.000975
# Profit                                                     -0.037437
# Year                                                        0.000023
# Month                                                      -0.000746
# Company_Pink Cab                                           -0.001235
# Company_Yellow Cab                                          0.001235
# City_ATLANTA GA                                             0.001809
# City_AUSTIN TX                                             -0.001902
# City_BOSTON MA                                              0.001666
# City_CHICAGO IL                                            -0.003713
# City_DALLAS TX                                              0.000657
# City_DENVER CO                                              0.001386
# City_LOS ANGELES CA                                        -0.001794
# City_MIAMI FL                                               0.000442
# City_NASHVILLE TN                                          -0.001033
# City_NEW YORK NY                                            0.002681
# City_ORANGE COUNTY                                          0.000032
# City_PHOENIX AZ                                            -0.001808
# City_PITTSBURGH PA                                          0.003586
# City_SACRAMENTO CA                                         -0.001180
# City_SAN DIEGO CA                                           0.001391
# Payment_Mode_Card                                           0.002270
# Payment_Mode_Cash                                          -0.002270
# Gender_Female                                              -0.000825
# Gender_Male                                                 0.000825
# Holiday_-                                                   0.004970
# Holiday_Christmas Day                                      -0.002518
# Holiday_Columbus Day                                       -0.000342
# Holiday_Independence Day                                    0.000012
# Holiday_Labor Day                                          -0.000978
# Holiday_Martin Luther King Jr. Day                         -0.001406
# Holiday_Memorial Day                                       -0.002608
# Holiday_New Year Day                                        0.000090
# Holiday_Presidents Day (Washingtons Birthday)              -0.002342
# Holiday_Thanksgiving Day                                   -0.002597
# Holiday_Veterans Day                                       -0.001994
# Day of Week_Friday                                         -0.163612
# Day of Week_Monday                                         -0.091054
# Day of Week_Saturday                                       -0.159454
# Day of Week_Sunday                                         -0.149348
# Day of Week_Thursday                                       -0.106477
# Day of Week_Tuesday                                        -0.090904
# Day of Week_Wednesday                                       1.000000
#
# [51 rows x 51 columns]

# %%
corr[['Profit']]
# Out:
#                                                  Profit
# Transaction ID                                -0.090022
# KM Travelled                                   0.475751
# Price Charged                                  0.879103
# Cost of Trip                                   0.503462
# Customer ID                                   -0.280051
# Age                                           -0.007396
# Income (USD/Month)                             0.004740
# Population                                     0.547125
# Users                                          0.466632
# Profit                                         1.000000
# Year                                          -0.063811
# Month                                         -0.097605
# Company_Pink Cab                              -0.282265
# Company_Yellow Cab                             0.282265
# City_ATLANTA GA                               -0.039210
# City_AUSTIN TX                                -0.034432
# City_BOSTON MA                                -0.185092
# City_CHICAGO IL                               -0.269924
# City_DALLAS TX                                 0.008294
# City_DENVER CO                                -0.032862
# City_LOS ANGELES CA                           -0.159143
# City_MIAMI FL                                 -0.030789
# City_NASHVILLE TN                             -0.062004
# City_NEW YORK NY                               0.554924
# City_ORANGE COUNTY                            -0.025979
# City_PHOENIX AZ                               -0.029307
# City_PITTSBURGH PA                            -0.034765
# City_SACRAMENTO CA                            -0.054979
# City_SAN DIEGO CA                             -0.033144
# Payment_Mode_Card                             -0.002328
# Payment_Mode_Cash                              0.002328
# Gender_Female                                 -0.020215
# Gender_Male                                    0.020215
# Holiday_-                                      0.000514
# Holiday_Christmas Day                         -0.007732
# Holiday_Columbus Day                           0.007470
# Holiday_Independence Day                      -0.003384
# Holiday_Labor Day                              0.006375
# Holiday_Martin Luther King Jr. Day            -0.006806
# Holiday_Memorial Day                          -0.001453
# Holiday_New Year Day                          -0.009589
# Holiday_Presidents Day (Washingtons Birthday)  0.004698
# Holiday_Thanksgiving Day                       0.004714
# Holiday_Veterans Day                           0.003461
# Day of Week_Friday                             0.026638
# Day of Week_Monday                            -0.034917
# Day of Week_Saturday                           0.022459
# Day of Week_Sunday                             0.059060
# Day of Week_Thursday                          -0.045958
# Day of Week_Tuesday                           -0.034289
# Day of Week_Wednesday                         -0.037437

# %%
np.abs(corr[['Profit']]).nlargest(20, 'Profit').reset_index()
# Out:
#                    index    Profit
# 0                 Profit  1.000000
# 1          Price Charged  0.879103
# 2       City_NEW YORK NY  0.554924
# 3             Population  0.547125
# 4           Cost of Trip  0.503462
# 5           KM Travelled  0.475751
# 6                  Users  0.466632
# 7       Company_Pink Cab  0.282265
# 8     Company_Yellow Cab  0.282265
# 9            Customer ID  0.280051
# 10       City_CHICAGO IL  0.269924
# 11        City_BOSTON MA  0.185092
# 12   City_LOS ANGELES CA  0.159143
# 13                 Month  0.097605
# 14        Transaction ID  0.090022
# 15                  Year  0.063811
# 16     City_NASHVILLE TN  0.062004
# 17    Day of Week_Sunday  0.059060
# 18    City_SACRAMENTO CA  0.054979
# 19  Day of Week_Thursday  0.045958

# %%
X_train = df_total_model[df_total_model['Year'] != 2018][np.abs(corr[['Profit']]).nlargest(20, 'Profit').reset_index()['index'][2:]]
y_train = df_total_model[df_total_model['Year'] != 2018]['Profit']
X_test = df_total_model[df_total_model['Year'] == 2018][np.abs(corr[['Profit']]).nlargest(20, 'Profit').reset_index()['index'][2:]]
y_test = df_total_model[df_total_model['Year'] == 2018]['Profit']

# %% [markdown]
# ### Linear Regression

# %%
reg = LinearRegression().fit(X_train, y_train)
reg.score(X_test, y_test)
# Out:
# 0.576227478461399

# %%
y_pred = reg.predict(X_test)
df_linear = pd.DataFrame({"y": y_test, "y_predict": y_pred})
df_linear
# Out:
#                y   y_predict
# 235829    7.8380  -81.707107
# 235830  149.5752  454.158118
# 235833  139.0200  119.869932
# 235835   31.3500  407.651480
# 235836  141.7480  104.980700
# ...          ...         ...
# 359386  191.6800  296.840594
# 359388    5.6100  -90.418499
# 359389   47.2500    7.147884
# 359390    4.1720 -122.619440
# 359391    0.9112  -79.050240
#
# [95584 rows x 2 columns]

# %%
mse=mean_squared_error(y_test, y_pred)
print(np.sqrt(mse))
# Out:
# 101.75954760737831

# %% [markdown]
# ### Ridge

# %%
reg = Ridge().fit(X_train, y_train)
reg.score(X_test, y_test)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:147: LinAlgWarning:
#
# Ill-conditioned matrix (rcond=4.45367e-19): result may not be accurate.
# 0.5763882412556443

# %%
y_pred = reg.predict(X_test)
df_linear = pd.DataFrame({"y": y_test, "y_predict": y_pred})
df_linear
# Out:
#                y   y_predict
# 235829    7.8380  -81.667389
# 235830  149.5752  453.790558
# 235833  139.0200  119.861426
# 235835   31.3500  407.267214
# 235836  141.7480  104.942546
# ...          ...         ...
# 359386  191.6800  296.804161
# 359388    5.6100  -90.297378
# 359389   47.2500    7.159827
# 359390    4.1720 -122.656870
# 359391    0.9112  -79.037588
#
# [95584 rows x 2 columns]

# %%
mse=mean_squared_error(y_test, y_pred)
print(np.sqrt(mse))
# Out:
# 101.7402439713668

# %% [markdown]
# ### XGBoost

# %%
xgb_model = xgb.XGBRegressor(objective="reg:squarederror", random_state=42).fit(X_train, y_train)
y_pred = xgb_model.predict(X_test)
mse=mean_squared_error(y_test, y_pred)
print(np.sqrt(mse))
# Out:
# 92.4144328314398

# %%
df_xgboost = pd.DataFrame({"y": y_test, "y_predict": y_pred})
df_xgboost
# Out:
#                y   y_predict
# 235829    7.8380   23.888582
# 235830  149.5752  318.049042
# 235833  139.0200  252.371826
# 235835   31.3500  210.548920
# 235836  141.7480  238.925690
# ...          ...         ...
# 359386  191.6800  303.773682
# 359388    5.6100   52.974232
# 359389   47.2500  143.789902
# 359390    4.1720   30.723171
# 359391    0.9112   15.230882
#
# [95584 rows x 2 columns]

# %% [markdown]
# #### Hyperparameter Searching for XGBoost

# %%
xgb_model = xgb.XGBRegressor()

params = {
    "colsample_bytree": uniform(0.7, 0.3),
    "gamma": uniform(0, 0.5),
    "learning_rate": uniform(0.03, 0.3), # default 0.1 
    "max_depth": randint(2, 6), # default 3
    "n_estimators": randint(100, 150), # default 100
    "subsample": uniform(0.6, 0.4)
}

search = RandomizedSearchCV(xgb_model, param_distributions=params, random_state=42, n_iter=20, cv=3, verbose=1, n_jobs=1, return_train_score=True)

search.fit(X_train, y_train)

report_best_scores(search.cv_results_, 1)
# Out:
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done  60 out of  60 | elapsed:  8.7min finished
# Model with rank: 1
# Mean validation score: 0.744 (std: 0.003)
# Parameters: {'colsample_bytree': 0.8835558684167137, 'gamma': 0.06974693032602092, 'learning_rate': 0.11764339456056544, 'max_depth': 5, 'n_estimators': 114, 'subsample': 0.7824279936868144}

# %%
xgb_model = xgb.XGBRegressor(colsample_bytree= 0.8835558684167137, gamma= 0.06974693032602092, learning_rate= 0.11764339456056544, max_depth= 5, n_estimators= 114, subsample= 0.7824279936868144).fit(X_train, y_train)
y_pred = xgb_model.predict(X_test)
mse=mean_squared_error(y_test, y_pred)
print(np.sqrt(mse))
# Out:
# 70.22724510947654

# %%
df_xgboost = pd.DataFrame({"y": y_test, "y_predict": y_pred})
df_xgboost
# Out:
#                y   y_predict
# 235829    7.8380   18.715492
# 235830  149.5752  294.532898
# 235833  139.0200  134.078400
# 235835   31.3500  249.422165
# 235836  141.7480  133.891861
# ...          ...         ...
# 359386  191.6800  295.593750
# 359388    5.6100   25.920586
# 359389   47.2500  115.316391
# 359390    4.1720   29.219027
# 359391    0.9112    5.878030
#
# [95584 rows x 2 columns]
